# %%
import pandas as pd

# %%
df = pd.read_csv (r'/Users/Chavez/Desktop/RB_Fantasy.csv')
df.head()
# Out:
#    Unnamed: 0           Player  Week Opponet  Win/Loss  Rushing Attempts  \
# 0           0    Tevin Coleman     1    at TB  W 31-17                 6
# 1           1   Raheem Mostert     1    at TB  W 31-17                 9
# 2           2      Matt Breida     1    at TB  W 31-17                15
# 3           3   Raheem Mostert     2   at CIN  W 41-17                13
# 4           4      Jeff Wilson     2   at CIN  W 41-17                10
#
#    Total Rushing Yards  Rushing Touchdowns  Passes Targetted  Passes caught  \
# 0                   23                   0                 3              2
# 1                   40                   0                 1              1
# 2                   37                   0                 1              0
# 3                   83                   0                 4              3
# 4                   34                   2                 0              0
#
#    Total passing yards  Recieving_Touchdowns  Fantasy Points Per Game
# ...

# %%
df.columns
# Out:
# Index([u'Unnamed: 0', u'Player', u'Week', u'Opponet ', u'Win/Loss',
#        u'Rushing Attempts', u'Total Rushing Yards', u'Rushing Touchdowns',
#        u'Passes Targetted', u'Passes caught', u'Total passing yards',
#        u'Recieving_Touchdowns', u'Fantasy Points Per Game'],
#       dtype='object')

# %%
df.rename(columns = {'Passes Targetted': 'Recieptions Targetted','Passes Targetted': 'Receptions Targetted','Passes caught': 'Receptions Caught','Total passing yards':'Total Receiving Yards' })
# Out:
#       Unnamed: 0            Player  Week Opponet  Win/Loss  Rushing Attempts  \
# 0              0     Tevin Coleman     1    at TB  W 31-17                 6
# 1              1    Raheem Mostert     1    at TB  W 31-17                 9
# 2              2       Matt Breida     1    at TB  W 31-17                15
# 3              3    Raheem Mostert     2   at CIN  W 41-17                13
# 4              4       Jeff Wilson     2   at CIN  W 41-17                10
# 5              5       Matt Breida     2   at CIN  W 41-17                12
# 6              6     Kyle Juszczyk     2   at CIN  W 41-17                 1
# 7              7       Jeff Wilson     3      PIT  W 24-20                 8
# 8              8       Matt Breida     3      PIT  W 24-20                14
# 9              9    Raheem Mostert     3      PIT  W 24-20                12
# 10            10     Kyle Juszczyk     3      PIT  W 24-20                 0
# ...

# %%
del df['Unnamed: 0']

# %%
df.rename(columns = {'Passes Targetted': 'Recieptions Targetted','Passes Targetted': 'Receptions Targetted','Passes caught': 'Receptions Caught','Total passing yards':'Total Receiving Yards' })
# Out:
#                 Player  Week Opponet  Win/Loss  Rushing Attempts  \
# 0        Tevin Coleman     1    at TB  W 31-17                 6
# 1       Raheem Mostert     1    at TB  W 31-17                 9
# 2          Matt Breida     1    at TB  W 31-17                15
# 3       Raheem Mostert     2   at CIN  W 41-17                13
# 4          Jeff Wilson     2   at CIN  W 41-17                10
# 5          Matt Breida     2   at CIN  W 41-17                12
# 6        Kyle Juszczyk     2   at CIN  W 41-17                 1
# 7          Jeff Wilson     3      PIT  W 24-20                 8
# 8          Matt Breida     3      PIT  W 24-20                14
# 9       Raheem Mostert     3      PIT  W 24-20                12
# 10       Kyle Juszczyk     3      PIT  W 24-20                 0
# 11         Matt Breida     5      CLE   W 31-3                11
# 12       Tevin Coleman     5      CLE   W 31-3                16
# ...

# %%
df.to_csv(r'/Users/Chavez/Desktop/RB_Data.csv', index = False)
