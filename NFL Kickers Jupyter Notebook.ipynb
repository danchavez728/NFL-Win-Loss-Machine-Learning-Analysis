# %%
#Dependencies
from matplotlib import pyplot as plt
import sklearn.datasets as dta
from scipy import stats
import numpy as np
import pandas as pd

# %%
# Load Kicker data set into pandas
Kicker_data = pd.read_csv("Resources\Kicker_Fantasy.csv")
Kicker_data.head()
# Out:
#              Player  Week Opponent Win/Loss  Field Goals Made  \
# 0   Harrison Butker     1   at JAC  W 40-26                 4
# 1   Harrison Butker     2    at LV  W 28-10                 0
# 2   Harrison Butker     3      BAL  W 33-28                 2
# 3   Harrison Butker     4   at DET  W 34-30                 2
# 4   Harrison Butker     5      IND  L 13-19                 2
#
#    Field Goals Attempted      FG%  Extra Point Made  Extra Point Attempted  \
# 0                      4  100.00%                 4                      4
# 1                      0    0.00%                 4                      4
# 2                      2  100.00%                 3                      4
# 3                      3   66.70%                 4                      4
# 4                      2  100.00%                 1                      1
#
#    FF Points
# 0         16
# 1          4
# 2          9
# 3         10
# 4          7

# %%
#Kicker_data["FG%"].astype(float).mean()
#Kicker_data['FG%'] = Kicker_data['FG%'].str.rstrip('%').astype('float') / 100.0

# %%
# Create a group based on the values in the 'Player' column
Player_group = Kicker_data.groupby('FG%')

# Count how many times each maker appears in our group
Player_makers = Player_group['FG%'].count()

Player_makers
# Out:
# FG%
# 0.00%       91
# 100.00%    303
# 25.00%       2
# 33.30%       6
# 50.00%      48
# 60.00%       2
# 66.70%      31
# 75.00%      24
# 80.00%       4
# 87.50%       1
# Name: FG%, dtype: int64

# %%
# Create a bar chart based off of the group series from before
count_chart = Player_makers.plot(kind='bar')

# Set the xlabel and ylabel using class methods
count_chart.set_xlabel("Field Goal Percentage")
count_chart.set_ylabel("Number of Players")

#Save the plotted figures as .pngs
#plt.savefig("Kicker_Bar.png")

#plt.show()
plt.tight_layout()
#plt.show()

#Save the plotted figures as .pngs
plt.savefig("Kicker_Bar.png")

# %%
# Set the 'Player' as our index
#Week_index = Kicker_data.set_index('Player')
#Week_index.head(11)
Kicker_data.head(50)
# Out:
#               Player  Week Opponent Win/Loss  Field Goals Made  \
# 0    Harrison Butker     1   at JAC  W 40-26                 4
# 1    Harrison Butker     2    at LV  W 28-10                 0
# 2    Harrison Butker     3      BAL  W 33-28                 2
# 3    Harrison Butker     4   at DET  W 34-30                 2
# 4    Harrison Butker     5      IND  L 13-19                 2
# 5    Harrison Butker     6      HOU  L 24-31                 1
# 6    Harrison Butker     7   at DEN   W 30-6                 3
# 7    Harrison Butker     8       GB  L 24-31                 1
# 8    Harrison Butker     9      MIN  W 26-23                 4
# 9    Harrison Butker    10   at TEN  L 32-35                 4
# 10   Harrison Butker    11   at LAC  W 24-17                 1
# 11   Harrison Butker    13       LV   W 40-9                 1
# 12   Harrison Butker    14    at NE  W 23-16                 3
# 13   Harrison Butker    15      DEN   W 23-3                 3
# 14   Harrison Butker    16   at CHI   W 26-3                 2
# 15   Harrison Butker    17      LAC  W 31-21                 1
# 16          Wil Lutz     1      HOU  W 30-28                 3
# 17          Wil Lutz     2   at LAR   L 9-27                 3
# 18          Wil Lutz     3   at SEA  W 33-27                 0
# 19          Wil Lutz     4      DAL  W 12-10                 4
# 20          Wil Lutz     5       TB  W 31-24                 1
# 21          Wil Lutz     6   at JAC   W 13-6                 2
# 22          Wil Lutz     7   at CHI  W 36-25                 2
# 23          Wil Lutz     8      ARI   W 31-9                 1
# 24          Wil Lutz    10      ATL   L 9-26                 3
# 25          Wil Lutz    11    at TB  W 34-17                 2
# 26          Wil Lutz    12      CAR  W 34-31                 2
# 27          Wil Lutz    13   at ATL  W 26-18                 4
# 28          Wil Lutz    14       SF  L 46-48                 2
# 29          Wil Lutz    15      IND   W 34-7                 2
# 30          Wil Lutz    16   at TEN  W 38-28                 1
# 31          Wil Lutz    17   at CAR  W 42-10                 0
# 32     Justin Tucker     1   at MIA  W 59-10                 1
# 33     Justin Tucker     2      ARI  W 23-17                 3
# 34     Justin Tucker     3    at KC  L 28-33                 1
# 35     Justin Tucker     4      CLE  L 25-40                 1
# 36     Justin Tucker     5   at PIT  W 26-23                 4
# 37     Justin Tucker     6      CIN  W 23-17                 3
# 38     Justin Tucker     7   at SEA  W 30-16                 3
# 39     Justin Tucker     9       NE  W 37-20                 1
# 40     Justin Tucker    10   at CIN  W 49-13                 0
# 41     Justin Tucker    11      HOU   W 41-7                 2
# 42     Justin Tucker    12   at LAR   W 45-6                 1
# 43     Justin Tucker    13       SF  W 20-17                 2
# 44     Justin Tucker    14   at BUF  W 24-17                 1
# 45     Justin Tucker    15      NYJ  W 42-21                 0
# 46     Justin Tucker    16   at CLE  W 31-15                 1
# 47     Justin Tucker    17      PIT  W 28-10                 4
# 48      Robbie Gould     1    at TB  W 31-17                 3
# 49      Robbie Gould     2   at CIN  W 41-17                 2
#
#     Field Goals Attempted      FG%  Extra Point Made  Extra Point Attempted  \
# 0                       4  100.00%                 4                      4
# 1                       0    0.00%                 4                      4
# 2                       2  100.00%                 3                      4
# 3                       3   66.70%                 4                      4
# 4                       2  100.00%                 1                      1
# 5                       2   50.00%                 3                      3
# 6                       3  100.00%                 3                      3
# 7                       2   50.00%                 3                      3
# 8                       4  100.00%                 2                      2
# 9                       5   80.00%                 2                      3
# 10                      1  100.00%                 3                      3
# 11                      1  100.00%                 5                      5
# 12                      3  100.00%                 2                      2
# 13                      3  100.00%                 0                      0
# 14                      2  100.00%                 2                      3
# 15                      1  100.00%                 4                      4
# 16                      4   75.00%                 3                      3
# 17                      3  100.00%                 0                      0
# 18                      0    0.00%                 3                      4
# 19                      4  100.00%                 0                      0
# 20                      1  100.00%                 4                      4
# 21                      2  100.00%                 1                      1
# 22                      4   50.00%                 4                      4
# 23                      2   50.00%                 4                      4
# 24                      3  100.00%                 0                      0
# 25                      2  100.00%                 4                      4
# 26                      2  100.00%                 4                      4
# 27                      4  100.00%                 2                      2
# 28                      2  100.00%                 4                      4
# 29                      2  100.00%                 4                      4
# 30                      1  100.00%                 5                      5
# 31                      0    0.00%                 6                      6
# 32                      1  100.00%                 8                      8
# 33                      3  100.00%                 2                      2
# 34                      1  100.00%                 1                      1
# 35                      1  100.00%                 2                      2
# 36                      4  100.00%                 2                      2
# 37                      3  100.00%                 2                      2
# 38                      3  100.00%                 3                      3
# 39                      1  100.00%                 4                      5
# 40                      0    0.00%                 7                      7
# 41                      3   66.70%                 5                      5
# 42                      1  100.00%                 6                      6
# 43                      2  100.00%                 2                      2
# 44                      1  100.00%                 3                      3
# 45                      0    0.00%                 4                      5
# 46                      1  100.00%                 4                      4
# 47                      4  100.00%                 2                      2
# 48                      4   75.00%                 2                      2
# 49                      3   66.70%                 5                      5
#
#     FF Points
# 0          16
# 1           4
# 2           9
# 3          10
# 4           7
# 5           6
# 6          12
# 7           6
# 8          14
# 9          14
# 10          6
# 11          8
# 12         11
# 13          9
# 14          8
# 15          7
# 16         12
# 17          9
# 18          3
# 19         12
# 20          7
# 21          7
# 22         10
# 23          7
# 24          9
# 25         10
# 26         10
# 27         14
# 28         10
# 29         10
# 30          8
# 31          6
# 32         11
# 33         11
# 34          4
# 35          5
# 36         14
# 37         11
# 38         12
# 39          7
# 40          7
# 41         11
# 42          9
# 43          8
# 44          6
# 45          4
# 46          7
# 47         14
# 48         11
# 49         11

# %%
# extracting greatest 5 
#large16 = Kicker_data[""].astype(str).nlargest(16) 
  
# display 
#large16

# %%
# Create a scatter plot which compares MPG to horsepower
Kicker_data.plot(kind="scatter", x="FG%", y="FF Points", grid=True, figsize=(8,8),
              title="FF Points vs. Field Goal Percentage")

#Save the plotted figures as .pngs

plt.savefig("Kicker_Scatter.png")

# Print our chart to the screen
plt.show()
                 
#Save the plotted figures as .pngs

#plt.savefig("Kicker_Scatter.png")

# %%
plt.hist(Kicker_data['FF Points'])
plt.xlabel('FF Points')
plt.ylabel('Player')
plt.show()
print(Kicker_data['FF Points'].mean())
# Out:
# 6.91796875

# %%
#plt.scatter(Kicker_data['FG%'],Kicker_data['Player'],c=Kicker_data['Week'])
#clb = plt.colorbar()
#plt.xlabel("FG%")
#plt.ylabel("Player")
#figsize = (1000,8)
#clb.set_label("Week")
#plt.show()

# %%
# Generate a scatter plot of year versus violent crime rate
Player = Kicker_data.iloc[:,0]
Field_Goal_Percentage = Kicker_data.iloc[:,6]
plt.scatter(Player,Field_Goal_Percentage)
plt.xticks(Player, rotation=90)
plt.xlabel('Player')
plt.ylabel('Field Goal Percentage')

#Save the plotted figures as .pngs

plt.savefig("Kicker_Scatter-Backup.png")
plt.show()

# %%
vc_slope, vc_int, vc_r, vc_p, vc_std_err = stats.linregress(Player, Field_Goal_Percentage)
